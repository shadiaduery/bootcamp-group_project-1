# %%
# Find a correlation or linear regression, peak dates (March - June), based on what are they correlated (pop density)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from sklearn.linear_model import LinearRegression

covid_clean_CA_TX = "Resources/covid_clean_CA_TX.csv"

# %%
covid_clean_CA_TX_df = pd.read_csv(covid_clean_CA_TX)

covid_clean_CA_TX_df.head(20)
# Out:
#    State  countyFIPS                 County Name  population  stateFIPS  \
# 0     CA        6000  Grand Princess Cruise Ship           0          6
# 1     CA        6001              Alameda County     1671329          6
# 2     CA        6003               Alpine County        1129          6
# 3     CA        6005               Amador County       39752          6
# 4     CA        6007                Butte County      219186          6
# 5     CA        6009            Calaveras County       45905          6
# 6     CA        6011               Colusa County       21547          6
# 7     CA        6013         Contra Costa County     1153526          6
# 8     CA        6015            Del Norte County       27812          6
# 9     CA        6017            El Dorado County      192843          6
# 10    CA        6019               Fresno County      999101          6
# 11    CA        6021                Glenn County       28393          6
# ...

# %%
total_by_state=covid_clean_CA_TX_df.groupby("State").sum()
total_by_state=total_by_state.reset_index()
total_by_state["State"]
# Out:
# 0    CA
# 1    TX
# Name: State, dtype: object

# %%
x_values = covid_clean_CA_TX_df[date]
y_values = covid_clean_CA_TX_df[total_case_numbers]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x values, y values) (covid_clean_CA_TX_df.iloc)
plt.xlabel('days March 1 - July 31')
plt.ylabel('total number of cases')
plt.show()

# %%
# Example 
# Add the linear regression equation and line to plot
# x_values = housing_data['RM']
# y_values = housing_data['MEDV']
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_values = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(x_values,y_values)
# plt.plot(x_values,regress_values,"r-")
# plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# plt.xlabel('Rooms in House')
# plt.ylabel('Median House Prices ($1000)')
# plt.show()

# TX shut down March 19 - April 30, reopen May 1, started new restrictions June 26  
# CA shut down March 19 - stage 2 reopn May 26, started new restricions June 28

# %%
# Example from Matplotlib HW
# # Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume 
# # for the Capomulin regimen
# corr=round(st.pearsonr(capavg['Weight (g)'],capavg['Tumor Volume (mm3)'])[0],2)
# print(f"The correlation between mouse weight and average tumor volume is {corr}")

# OUTPUT   The correlation between mouse weight and average tumor volume is 0.84

# model=st.linregress(capavg['Weight (g)'],capavg['Tumor Volume (mm3)'])
# model

# OUTPUT   LinregressResult(slope=0.9544396890241045, intercept=21.552160532685015, 
# rvalue=0.8419363424694718, pvalue=1.3225722434712642e-07, stderr=0.1275435903320134)

# #capavg['Weight (g)']
# mslope = 0.9544396890241045
# bintercept = 21.552160532685015

# y_values = capavg['Weight (g)']*mslope+bintercept
# plt.scatter(capavg['Weight (g)'],capavg['Tumor Volume (mm3)'])
# plt.plot(capavg['Weight (g)'],y_values,color="red")
# plt.xlabel('Weight(g)')
# plt.ylabel('Average Tumore Volume (mm3)')

# plt.savefig('linearregression')
# plt.show()
